# %%
import pandas as pd
import numpy as np

# %%
dict1 = {
"name":['harry','rohan','skillf','shubh'],
"marks": [92, 34, 24, 17],
"city": ['rampur', 'kolkata', 'bareilly', 'antarctica']
}

# %%
df = pd.DataFrame(dict1)
df
# Out:
#      name  marks        city
# 0   harry     92      rampur
# 1   rohan     34     kolkata
# 2  skillf     24    bareilly
# 3   shubh     17  antarctica

# %% [markdown]
# it is used for df into csv

# %%
df.to_csv('friend.csv')

# %% [markdown]
# it will show starting rows

# %%
df.head(2)
# Out:
#     name  marks     city
# 0  harry     92   rampur
# 1  rohan     34  kolkata

# %% [markdown]
# it will show last rows

# %%
df.tail (3)
# Out:
#      name  marks        city
# 1   rohan     34     kolkata
# 2  skillf     24    bareilly
# 3   shubh     17  antarctica

# %% [markdown]
# it is for statical analysis

# %%
df.describe ()
# Out:
#           marks
# count   4.00000
# mean   41.75000
# std    34.21866
# min    17.00000
# 25%    22.25000
# 50%    29.00000
# 75%    48.50000
# max    92.00000

# %% [markdown]
# to read csv file

# %%
df=pd.read_csv('friend.csv')
df
# Out:
#    Unnamed: 0    name  marks        city
# 0           0   harry     92      rampur
# 1           1   rohan     34     kolkata
# 2           2  skillf     24    bareilly
# 3           3   shubh     17  antarctica

# %% [markdown]
# to show particular column

# %%
df['name']
# Out:
# 0     harry
# 1     rohan
# 2    skillf
# 3     shubh
# Name: name, dtype: object

# %% [markdown]
# for change the value of any row

# %%
df['marks'][0]= 45
# Out:
# /tmp/ipython-input-16-1099992204.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['marks'][0]= 45
# /tmp/ipython-input-16-1099992204.py:1: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#    Unnamed: 0    name  marks        city
# 0           0   harry     45      rampur
# 1           1   rohan     34     kolkata
# 2           2  skillf     24    bareilly
# 3           3   shubh     17  antarctica

# %% [markdown]
# it is for change index of csv

# %%
df.index= ['first','second','third','fourth']
df
# Out:
#         Unnamed: 0    name  marks        city
# first            0   harry     45      rampur
# second           1   rohan     34     kolkata
# third            2  skillf     24    bareilly
# fourth           3   shubh     17  antarctica

# %% [markdown]
# random series

# %%
ser= pd.Series(np.random.rand(34))
ser
# Out:
# 0     0.142412
# 1     0.590440
# 2     0.606485
# 3     0.561187
# 4     0.032784
# 5     0.916864
# 6     0.109622
# 7     0.982255
# 8     0.436452
# 9     0.196231
# 10    0.612533
# 11    0.753873
# 12    0.455181
# 13    0.520386
# 14    0.777400
# 15    0.897706
# 16    0.285668
# 17    0.042064
# 18    0.291486
# 19    0.411757
# 20    0.029118
# 21    0.297558
# 22    0.091844
# 23    0.947162
# 24    0.945601
# 25    0.660078
# 26    0.982396
# 27    0.670577
# 28    0.797043
# 29    0.372660
# 30    0.133665
# 31    0.345596
# 32    0.702748
# 33    0.772889
# dtype: float64

# %% [markdown]
# type of series

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf=pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
newdf.head(5)
# Out:
#           0         1         2         3         4
# 0  0.022047  0.835791  0.917273  0.061404  0.258225
# 1  0.159562  0.494049  0.561597  0.070215  0.351429
# 2  0.720369  0.918355  0.185838  0.853360  0.291065
# 3  0.400786  0.488331  0.300192  0.103281  0.867934
# 4  0.019481  0.945016  0.569508  0.196651  0.161849

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe ()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0.487949    0.506930    0.498432    0.481941    0.487867
# std      0.297894    0.286275    0.298504    0.304753    0.297893
# min      0.000571    0.000119    0.002119    0.000099    0.000096
# 25%      0.240744    0.256015    0.232532    0.211846    0.235361
# 50%      0.472295    0.515025    0.498268    0.449406    0.474438
# 75%      0.741364    0.760241    0.742224    0.757401    0.736504
# max      0.999221    0.999306    0.993641    0.990809    0.998508

# %% [markdown]
# datatypes of dataframe

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %% [markdown]
# change into numpy

# %%
newdf.to_numpy ()
# Out:
# array([[0.02204739, 0.83579076, 0.91727318, 0.061404  , 0.25822481],
#        [0.15956159, 0.4940493 , 0.56159735, 0.07021491, 0.3514293 ],
#        [0.72036914, 0.91835536, 0.18583755, 0.8533598 , 0.29106527],
#        ...,
#        [0.36313471, 0.75808057, 0.02751381, 0.16975588, 0.09281121],
#        [0.44138046, 0.35811338, 0.57076267, 0.58722339, 0.69475148],
#        [0.00909184, 0.1626357 , 0.14810432, 0.15903569, 0.06747569]])

# %% [markdown]
# transpose

# %%
newdf.T
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.022047  0.159562  0.720369  0.400786  0.019481  0.389519  0.055080
# 1  0.835791  0.494049  0.918355  0.488331  0.945016  0.773347  0.882865
# 2  0.917273  0.561597  0.185838  0.300192  0.569508  0.603422  0.137448
# 3  0.061404  0.070215  0.853360  0.103281  0.196651  0.912357  0.130084
# 4  0.258225  0.351429  0.291065  0.867934  0.161849  0.842344  0.488786
#
#         7         8         9    ...       324       325       326       327  \
# 0  0.957681  0.367373  0.734938  ...  0.938451  0.853661  0.061899  0.894289
# 1  0.738827  0.735180  0.548465  ...  0.083312  0.134832  0.846204  0.904086
# 2  0.145250  0.648873  0.674559  ...  0.369522  0.763303  0.852724  0.881343
# 3  0.334291  0.741047  0.747350  ...  0.253088  0.814817  0.756021  0.930740
# 4  0.509674  0.258006  0.353110  ...  0.852362  0.151567  0.348746  0.035897
#
#         328       329       330       331       332       333
# ...

# %% [markdown]
# for sort the data,
# axis=1 for column,
# axis= 0 for row

# %%
newdf.sort_index(axis=1,ascending=False)
# Out:
#             4         3         2         1         0
# 0    0.258225  0.061404  0.917273  0.835791  0.022047
# 1    0.351429  0.070215  0.561597  0.494049  0.159562
# 2    0.291065  0.853360  0.185838  0.918355  0.720369
# 3    0.867934  0.103281  0.300192  0.488331  0.400786
# 4    0.161849  0.196651  0.569508  0.945016  0.019481
# ..        ...       ...       ...       ...       ...
# 329  0.435312  0.129240  0.542135  0.040584  0.449099
# 330  0.932527  0.853805  0.506347  0.540004  0.252241
# 331  0.092811  0.169756  0.027514  0.758081  0.363135
# 332  0.694751  0.587223  0.570763  0.358113  0.441380
# 333  0.067476  0.159036  0.148104  0.162636  0.009092
#
# [334 rows x 5 columns]

# %% [markdown]
# to change the value , return a new dataframe but not copy df

# %%
newdf.loc[0,0]=254
newdf.head(2)
# Out:
#             0         1         2         3         4
# 0  254.000000  0.835791  0.917273  0.061404  0.258225
# 1    0.159562  0.494049  0.561597  0.070215  0.351429

# %% [markdown]
# find the value by index no;

# %%
newdf.iloc[0,4]
# Out:
# np.float64(0.2582248133209487)

# %%
newdf.iloc[[0,1],[2,4]]
# Out:
#           2         4
# 0  0.917273  0.258225
# 1  0.561597  0.351429

# %% [markdown]
# to delete row and column , by defaul it takes row as axis

# %%
newdf.drop([2,3],axis=1)
# Out:
#               0         1         4
# 0    254.000000  0.835791  0.258225
# 1      0.159562  0.494049  0.351429
# 2      0.720369  0.918355  0.291065
# 3      0.400786  0.488331  0.867934
# 4      0.019481  0.945016  0.161849
# ..          ...       ...       ...
# 329    0.449099  0.040584  0.435312
# 330    0.252241  0.540004  0.932527
# 331    0.363135  0.758081  0.092811
# 332    0.441380  0.358113  0.694751
# 333    0.009092  0.162636  0.067476
#
# [334 rows x 3 columns]

# %% [markdown]
# reset the index , drop =True use for delete extra column of name as index

# %%
newdf.reset_index(drop= True , inplace=True)

# %%
newdf.head(3)
# Out:
#             0         1         2         3         4
# 0  254.000000  0.835791  0.917273  0.061404  0.258225
# 1    0.159562  0.494049  0.561597  0.070215  0.351429
# 2    0.720369  0.918355  0.185838  0.853360  0.291065

# %%
newdf.loc[:,[2,3]]=None
newdf.head(3)
# Out:
# /tmp/ipython-input-40-3292870052.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'None' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   newdf.loc[:,[2,3]]=None
# /tmp/ipython-input-40-3292870052.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'None' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   newdf.loc[:,[2,3]]=None
#             0         1     2     3         4
# 0  254.000000  0.835791  None  None  0.258225
# 1    0.159562  0.494049  None  None  0.351429
# 2    0.720369  0.918355  None  None  0.291065

# %%
newdf[3].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 329    True
# 330    True
# 331    True
# 332    True
# 333    True
# Name: 3, Length: 334, dtype: bool

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334 entries, 0 to 333
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       334 non-null    float64
#  1   1       334 non-null    float64
#  2   2       0 non-null      object
#  3   3       0 non-null      object
#  4   4       334 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 13.2+ KB
